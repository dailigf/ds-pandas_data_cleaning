# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#More-Pandas" data-toc-modified-id="More-Pandas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>More Pandas</a></span><ul class="toc-item"><li><span><a href="#Loading-the-Data" data-toc-modified-id="Loading-the-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Loading the Data</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis (EDA)</a></span><ul class="toc-item"><li><span><a href="#Inspecting-the-Data" data-toc-modified-id="Inspecting-the-Data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Inspecting the Data</a></span></li><li><span><a href="#Question-1:-What-animal-types-are-in-the-dataset?" data-toc-modified-id="Question-1:-What-animal-types-are-in-the-dataset?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Question 1: What animal types are in the dataset?</a></span></li><li><span><a href="#Question-2:-What-&quot;Other&quot;-animals-are-in-the-dataset?" data-toc-modified-id="Question-2:-What-&quot;Other&quot;-animals-are-in-the-dataset?-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Question 2: What "Other" animals are in the dataset?</a></span></li><li><span><a href="#Question-3:-How-old-are-the-animals-in-our-dataset?" data-toc-modified-id="Question-3:-How-old-are-the-animals-in-our-dataset?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Question 3: How old are the animals in our dataset?</a></span><ul class="toc-item"><li><span><a href="#Series.map()" data-toc-modified-id="Series.map()-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span><code>Series.map()</code></a></span></li><li><span><a href="#More-Sophisticated-Mapping" data-toc-modified-id="More-Sophisticated-Mapping-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>More Sophisticated Mapping</a></span></li><li><span><a href="#Lambda-Functions" data-toc-modified-id="Lambda-Functions-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Lambda Functions</a></span></li></ul></li></ul></li><li><span><a href="#Handling-Missing-Data" data-toc-modified-id="Handling-Missing-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Handling Missing Data</a></span><ul class="toc-item"><li><span><a href="#Fill-with-a-Relevant-Value" data-toc-modified-id="Fill-with-a-Relevant-Value-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Fill with a Relevant Value</a></span></li><li><span><a href="#Fill-with-a-Reasonable-Value" data-toc-modified-id="Fill-with-a-Reasonable-Value-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Fill with a Reasonable Value</a></span></li><li><span><a href="#Specify-That-the-Data-Were-Missing" data-toc-modified-id="Specify-That-the-Data-Were-Missing-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Specify That the Data Were Missing</a></span></li><li><span><a href="#Drop-Missing-Data" data-toc-modified-id="Drop-Missing-Data-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Drop Missing Data</a></span></li><li><span><a href="#Comparing-Before-and-After" data-toc-modified-id="Comparing-Before-and-After-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Comparing Before and After</a></span></li></ul></li><li><span><a href="#Level-Up:-.applymap()" data-toc-modified-id="Level-Up:-.applymap()-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Level Up: <code>.applymap()</code></a></span></li><li><span><a href="#Level-Up:-Faster-NumPy-Methods" data-toc-modified-id="Level-Up:-Faster-NumPy-Methods-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Level Up: Faster NumPy Methods</a></span><ul class="toc-item"><li><span><a href="#NumPy's-where()-Method" data-toc-modified-id="NumPy's-where()-Method-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>NumPy's <code>where()</code> Method</a></span></li><li><span><a href="#NumPy's-select()-Method" data-toc-modified-id="NumPy's-select()-Method-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>NumPy's <code>select()</code> Method</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![panda](http://res.freestockphotos.biz/thumbs/3/3173-illustration-of-a-giant-panda-eating-bamboo-th.png)

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Objectives

# %% [markdown]
# - Use lambda functions and DataFrame methods to transform data
# - Handle missing data

# %% [markdown]
# # More Pandas

# %% [markdown]
# Suppose you were interested in opening an animal shelter. To inform your planning, it would be useful to analyze data from other shelters to understand their operations. In this lecture, we'll analyze animal outcome data from the Austin Animal Center.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Let's take a moment to examine the [Austin Animal Center data set](https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Outcomes/9t4d-g238/data).
#
# We can also ingest the data right off the web, as we do below. The code below will load JSON data for the last 1000 animals to leave the center from this [JSON file](https://data.austintexas.gov/resource/9t4d-g238.json).

# %%
json_url = 'https://data.austintexas.gov/resource/9t4d-g238.json'
animals = pd.read_json(json_url)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Exploring a new dataset is essential for understanding what it contains. This will generate ideas for processing the data and questions to try to answer in further analysis.

# %% [markdown]
# ## Inspecting the Data

# %% [markdown]
# Let's take a look at a few rows of data.

# %%
animals.head(10)
# Out:
#   animal_id       name            datetime                monthyear  \
# 0   A857248     *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557       Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710    A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440    Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946       Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
# 5   A767668    *Julius 2022-06-02 16:37:00  2022-06-02T16:37:00.000
# 6   A858692  Princessa 2022-06-02 16:14:00  2022-06-02T16:14:00.000
# 7   A849582      Lucas 2022-06-02 16:08:00  2022-06-02T16:08:00.000
# 8   A858685     Punken 2022-06-02 15:55:00  2022-06-02T15:55:00.000
# 9   A857573   *Msh Msh 2022-06-02 15:38:00  2022-06-02T15:38:00.000
#
#              date_of_birth     outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000         Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000         Adoption             NaN         Dog
# 2  2022-02-28T00:00:00.000         Adoption             NaN         Cat
# 3  2018-10-04T00:00:00.000         Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000         Transfer         Partner         Dog
# 5  2017-06-05T00:00:00.000         Transfer             Snr         Cat
# 6  2019-06-02T00:00:00.000         Transfer         Partner         Dog
# 7  2021-11-10T00:00:00.000  Return to Owner             NaN         Dog
# 8  2022-01-02T00:00:00.000  Return to Owner             NaN         Dog
# 9  2020-05-18T00:00:00.000         Adoption             NaN         Cat
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
# 5    Neutered Male          4 years     Domestic Shorthair Mix
# 6    Intact Female          3 years                        Pug
# 7    Neutered Male         6 months     Labrador Retriever Mix
# 8    Intact Female         4 months     Labrador Retriever Mix
# 9    Neutered Male          2 years     Domestic Shorthair Mix
#
#                  color
# 0  Brown Brindle/White
# 1             Tricolor
# 2                 Blue
# 3          White/Black
# 4          Brown/White
# 5    Brown Tabby/White
# 6                 Fawn
# 7  Brown Brindle/White
# 8            White/Tan
# 9     Blue Tabby/White

# %% [markdown]
# The `info()` and `describe()` provide a useful overview of the data.

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   animal_id         1000 non-null   object
#  1   name              829 non-null    object
#  2   datetime          1000 non-null   datetime64[ns]
#  3   monthyear         1000 non-null   object
#  4   date_of_birth     1000 non-null   object
#  5   outcome_type      1000 non-null   object
#  6   outcome_subtype   555 non-null    object
#  7   animal_type       1000 non-null   object
#  8   sex_upon_outcome  1000 non-null   object
#  9   age_upon_outcome  1000 non-null   object
#  10  breed             1000 non-null   object
#  11  color             1000 non-null   object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 93.9+ KB

# %% [markdown]
# > We can see we have some missing data. Specifically in the `outcome_type`, `outcome_subtype`, and `name` columns.

# %%
animals.describe()
# Out:
# <ipython-input-5-3885fd60d0c1>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   animals.describe()
#        animal_id  name             datetime                monthyear  \
# count       1000   829                 1000                     1000
# unique       984   766                  814                      814
# top      A856037  King  2022-05-18 13:04:00  2022-05-18T13:04:00.000
# freq           3     4                    7                        7
# first        NaN   NaN  2022-05-05 16:08:00                      NaN
# last         NaN   NaN  2022-06-02 19:01:00                      NaN
#
#                   date_of_birth outcome_type outcome_subtype animal_type  \
# count                      1000         1000             555        1000
# unique                      461            8              14           4
# top     2022-03-02T00:00:00.000     Adoption         Partner         Dog
# freq                         34          440             249         500
# first                       NaN          NaN             NaN         NaN
# last                        NaN          NaN             NaN         NaN
#
#        sex_upon_outcome age_upon_outcome               breed        color
# count              1000             1000                1000         1000
# unique                5               37                 148          101
# top       Neutered Male         2 months  Domestic Shorthair  Black/White
# freq                301              209                 295          103
# first               NaN              NaN                 NaN          NaN
# last                NaN              NaN                 NaN          NaN

# %%
# Use value counts to check a categorical feature's distribution

animals['color'].value_counts()
# Out:
# Black/White           103
# Black                  90
# Brown Tabby            67
# White                  43
# Brown Tabby/White      38
#                      ...
# Chocolate Point         1
# Buff/Black              1
# Tortie Point/White      1
# White/Blue Tabby        1
# Gray/Tan                1
# Name: color, Length: 101, dtype: int64

# %% [markdown]
# Now that we have a sense of the data available to us, we can focus in on some more specific questions to dig into. These questions may or may not be directly relevant to your goal (e.g. helping plan a new shelter), but will always help you gain a better understanding of your data.
#
# In your EDA notebooks, **markdown** will be especially helpful in tracking these questions and your methods of answering the questions.

# %% [markdown]
# ## Question 1: What animal types are in the dataset?

# %% [markdown]
# We can then begin thinking about what parts of the DataFrame we need to answer the question.

# %% [markdown]
# * What features do we need?
#  - "animal_type"
# * What type of logic and calculation do we perform?
#  - Let's use `.value_counts()` to count the different animal types
# * What type of visualization would help us answer the question?
#  - A bar chart would be good for this purpose

# %%
animals['animal_type'].value_counts()
# Out:
# Dog      500
# Cat      450
# Other     47
# Bird       3
# Name: animal_type, dtype: int64

# %%
fig, ax = plt.subplots()

animal_type_values = animals['animal_type'].value_counts()

ax.barh(
    y=animal_type_values.index,
    width=animal_type_values.values
)
ax.set_xlabel('count');

# %%
animals['animal_type'].hist();

# %% [markdown]
# Questions lead to other questions. For the above example, the visualization raises the question...

# %% [markdown]
# ## Question 2: What "Other" animals are in the dataset?

# %% [markdown]
# To find out, we need to know whether the type of animal for "Other" is in our dataset - and if so, where to find it.

# %% [markdown]
# **Discussion**: Where might we look to find animal types within the Other category?
#
# <details>
#     <summary>
#         Answer
#     </summary>
#         The breed column.
# </details>

# %%
# Your exploration here
animals.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption             NaN         Dog
# 2  2022-02-28T00:00:00.000     Adoption             NaN         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color
# 0  Brown Brindle/White
# 1             Tricolor
# 2                 Blue
# 3          White/Black
# 4          Brown/White

# %% [markdown]
# Let's use that column to answer our question.

# %%
mask_other_animals = animals['animal_type'] == 'Other'
animals[mask_other_animals]['breed'].value_counts()
# Out:
# Bat           14
# Guinea Pig    13
# Raccoon        9
# Fox            3
# Skunk          2
# Lionhead       2
# Hamster        1
# Rabbit Sh      1
# Squirrel       1
# Ferret         1
# Name: breed, dtype: int64

# %% [markdown]
# ## Question 3: How old are the animals in our dataset?

# %% [markdown]
# Let's try to answer this with the `age_upon_outcome` variable to learn some new `pandas` tools.

# %%
animals['age_upon_outcome'].value_counts()
# Out:
# 2 months     209
# 2 years      167
# 1 year       114
# 4 months      40
# 3 years       40
# 4 years       32
# 4 weeks       29
# 1 month       29
# 3 months      29
# 5 months      27
# 3 weeks       26
# 6 months      26
# 2 weeks       21
# 1 weeks       21
# 3 days        18
# NULL          17
# 7 months      16
# 6 years       15
# 7 years       14
# 5 years       14
# 10 months     14
# 8 years       11
# 10 years       9
# 12 years       8
# 1 day          8
# 8 months       7
# 9 months       6
# 5 days         6
# 13 years       5
# 9 years        5
# 14 years       5
# 11 years       3
# 15 years       3
# 1 week         3
# 18 years       1
# 19 years       1
# 11 months      1
# Name: age_upon_outcome, dtype: int64

# %% [markdown]
# ### `Series.map()`

# %% [markdown]
# The `.map()` method applies a transformation to every entry in the Series. This transformation  "maps" each value from the Series to a new value. A transformation can be defined by a function, Series, or dictionary - usually we'll use functions.

# %% [markdown]
# The `.apply()` method is similar to the `.map()` method for Series, but can only use functions. It has more powerful uses when working with DataFrames.

# %%
def one_year(age):
    if age == '1 year':
        return '1 years'
    else:
        return age

# %%
animals['new_age1'] = animals['age_upon_outcome'].map(one_year)
animals['new_age1'].value_counts()
# Out:
# 2 months     209
# 2 years      167
# 1 years      114
# 4 months      40
# 3 years       40
# 4 years       32
# 3 months      29
# 1 month       29
# 4 weeks       29
# 5 months      27
# 6 months      26
# 3 weeks       26
# 1 weeks       21
# 2 weeks       21
# 3 days        18
# NULL          17
# 7 months      16
# 6 years       15
# 10 months     14
# 7 years       14
# 5 years       14
# 8 years       11
# 10 years       9
# 1 day          8
# 12 years       8
# 8 months       7
# 9 months       6
# 5 days         6
# 9 years        5
# 14 years       5
# 13 years       5
# 11 years       3
# 15 years       3
# 1 week         3
# 18 years       1
# 11 months      1
# 19 years       1
# Name: new_age1, dtype: int64

# %% [markdown]
# ### More Sophisticated Mapping

# %% [markdown]
# Let's use `.map()` to turn sex_upon_outcome into a category with three values (called **ternary**): male, female, or unknown.

# %% [markdown]
# First, explore the unique values:

# %%
animals['sex_upon_outcome'].unique()
# Out:
# array(['Spayed Female', 'Neutered Male', 'Intact Female', 'Intact Male',
#        'Unknown'], dtype=object)

# %%
def sex_mapper(status):
    if status in ['Neutered Male', 'Intact Male']:
        return 'Male'
    elif status in ['Spayed Female', 'Intact Female']:
        return 'Female'
    else:
        return 'Unknown'

# %%
animals['new_sex1'] = animals['sex_upon_outcome'].map(sex_mapper)
animals.loc[:, ['sex_upon_outcome', 'new_sex1']]
# Out:
#     sex_upon_outcome new_sex1
# 0      Spayed Female   Female
# 1      Neutered Male     Male
# 2      Spayed Female   Female
# 3      Neutered Male     Male
# 4      Intact Female   Female
# ..               ...      ...
# 995      Intact Male     Male
# 996    Spayed Female   Female
# 997          Unknown  Unknown
# 998    Spayed Female   Female
# 999    Intact Female   Female
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Lambda Functions

# %% [markdown]
# Simple functions can be defined just when you need them, when you would call the function. These are called **lambda functions**. These functions are **anonymous** and disappear immediately after use.

# %% [markdown]
# Let's use a lambda function to get rid of 'Other' in the "animal_type' column.

# %%
animals[animals['animal_type'] == 'Other']
# Out:
#     animal_id            name            datetime                monthyear  \
# 127   A858462             NaN 2022-05-30 15:26:00  2022-05-30T15:26:00.000
# 128   A858365         A858365 2022-05-30 15:08:00  2022-05-30T15:08:00.000
# 173   A858321             NaN 2022-05-28 08:01:00  2022-05-28T08:01:00.000
# 211   A858251             NaN 2022-05-27 08:08:00  2022-05-27T08:08:00.000
# 220   A858241             NaN 2022-05-26 18:34:00  2022-05-26T18:34:00.000
# 257   A858176         A858176 2022-05-26 10:43:00  2022-05-26T10:43:00.000
# 264   A858089         A858089 2022-05-25 18:00:00  2022-05-25T18:00:00.000
# 273   A858112             NaN 2022-05-25 14:56:00  2022-05-25T14:56:00.000
# 274   A858109             NaN 2022-05-25 14:54:00  2022-05-25T14:54:00.000
# 275   A858099             NaN 2022-05-25 14:53:00  2022-05-25T14:53:00.000
# 294   A858010             NaN 2022-05-25 11:22:00  2022-05-25T11:22:00.000
# 299   A857782         A857782 2022-05-25 07:10:00  2022-05-25T07:10:00.000
# 300   A857781         A857781 2022-05-25 07:09:00  2022-05-25T07:09:00.000
# 316   A857596      *Elizabeth 2022-05-24 14:19:00  2022-05-24T14:19:00.000
# 389   A857882             NaN 2022-05-23 12:49:00  2022-05-23T12:49:00.000
# 395   A857815           Benji 2022-05-23 11:30:00  2022-05-23T11:30:00.000
# 402   A857868             NaN 2022-05-23 10:50:00  2022-05-23T10:50:00.000
# 413   A857872             NaN 2022-05-22 13:58:00  2022-05-22T13:58:00.000
# 414   A857789             NaN 2022-05-22 11:10:00  2022-05-22T11:10:00.000
# 446   A857774             NaN 2022-05-20 16:50:00  2022-05-20T16:50:00.000
# 460   A856582        *Pancake 2022-05-20 15:38:00  2022-05-20T15:38:00.000
# 461   A857515  *Cherry Garcia 2022-05-20 15:38:00  2022-05-20T15:38:00.000
# 462   A857516      *Moophoria 2022-05-20 15:37:00  2022-05-20T15:37:00.000
# 513   A857666             NaN 2022-05-20 08:55:00  2022-05-20T08:55:00.000
# 536   A857502             NaN 2022-05-19 08:48:00  2022-05-19T08:48:00.000
# 537   A857503             NaN 2022-05-19 08:47:00  2022-05-19T08:47:00.000
# 538   A857641             NaN 2022-05-19 08:44:00  2022-05-19T08:44:00.000
# 539   A857297             NaN 2022-05-19 07:35:00  2022-05-19T07:35:00.000
# 544   A857603             NaN 2022-05-18 16:36:00  2022-05-18T16:36:00.000
# 548   A857567         Raccoon 2022-05-18 15:11:00  2022-05-18T15:11:00.000
# 676   A857299             NaN 2022-05-14 16:20:00  2022-05-14T16:20:00.000
# 688   A857265             NaN 2022-05-14 07:55:00  2022-05-14T07:55:00.000
# 689   A857223          Reeves 2022-05-13 19:00:00  2022-05-13T19:00:00.000
# 690   A857222           Keanu 2022-05-13 18:57:00  2022-05-13T18:57:00.000
# 691   A857222           Keanu 2022-05-13 18:57:00  2022-05-13T18:57:00.000
# 710   A857180       Sunflower 2022-05-13 14:38:00  2022-05-13T14:38:00.000
# 791   A856756         A856756 2022-05-11 09:37:00  2022-05-11T09:37:00.000
# 792   A856793             NaN 2022-05-11 09:31:00  2022-05-11T09:31:00.000
# 840   A856714         A856714 2022-05-09 19:02:00  2022-05-09T19:02:00.000
# 841   A856715         A856715 2022-05-09 19:02:00  2022-05-09T19:02:00.000
# 842   A856711         A856711 2022-05-09 19:01:00  2022-05-09T19:01:00.000
# 843   A856712         A856712 2022-05-09 19:01:00  2022-05-09T19:01:00.000
# 844   A856368          Shadow 2022-05-09 19:00:00  2022-05-09T19:00:00.000
# 845   A856369          Peanut 2022-05-09 19:00:00  2022-05-09T19:00:00.000
# 887   A856827             NaN 2022-05-09 09:34:00  2022-05-09T09:34:00.000
# 903   A856713         A856713 2022-05-09 00:00:00  2022-05-09T00:00:00.000
# 905   A856664         Raccoon 2022-05-08 08:06:00  2022-05-08T08:06:00.000
#
#                date_of_birth     outcome_type outcome_subtype animal_type  \
# 127  2020-05-30T00:00:00.000       Euthanasia     Rabies Risk       Other
# 128  2020-05-28T00:00:00.000       Euthanasia     Rabies Risk       Other
# 173  2020-05-27T00:00:00.000       Euthanasia     Rabies Risk       Other
# 211  2020-05-26T00:00:00.000       Euthanasia     Rabies Risk       Other
# 220  2020-05-26T00:00:00.000       Euthanasia     Rabies Risk       Other
# 257  2020-05-26T00:00:00.000       Euthanasia     Rabies Risk       Other
# 264  2020-05-25T00:00:00.000       Euthanasia     Rabies Risk       Other
# 273  2022-03-25T00:00:00.000       Euthanasia     Rabies Risk       Other
# 274  2022-03-25T00:00:00.000       Euthanasia     Rabies Risk       Other
# 275  2021-05-25T00:00:00.000       Euthanasia     Rabies Risk       Other
# 294  2020-05-24T00:00:00.000       Euthanasia       Suffering       Other
# 299  2021-05-20T00:00:00.000         Transfer         Partner       Other
# 300  2021-05-20T00:00:00.000         Transfer         Partner       Other
# 316  2021-05-18T00:00:00.000         Transfer         Partner       Other
# 389  2020-05-22T00:00:00.000       Euthanasia     Rabies Risk       Other
# 395  2021-01-03T00:00:00.000  Return to Owner             NaN       Other
# 402  2021-05-22T00:00:00.000       Euthanasia     Rabies Risk       Other
# 413  2021-05-22T00:00:00.000       Euthanasia             NaN       Other
# 414  2020-05-21T00:00:00.000       Euthanasia     Rabies Risk       Other
# 446  2021-05-20T00:00:00.000       Euthanasia     Rabies Risk       Other
# 460  2020-05-05T00:00:00.000         Transfer         Partner       Other
# 461  2021-11-17T00:00:00.000         Transfer         Partner       Other
# 462  2021-11-17T00:00:00.000         Transfer         Partner       Other
# 513  2020-05-19T00:00:00.000       Euthanasia             NaN       Other
# 536  2021-05-17T00:00:00.000       Euthanasia     Rabies Risk       Other
# 537  2021-05-17T00:00:00.000       Euthanasia       Suffering       Other
# 538  2020-05-18T00:00:00.000       Euthanasia          At Vet       Other
# 539  2021-05-14T00:00:00.000       Euthanasia       Suffering       Other
# 544  2020-05-18T00:00:00.000       Euthanasia     Rabies Risk       Other
# 548  2020-05-18T00:00:00.000       Euthanasia     Rabies Risk       Other
# 676  2021-05-14T00:00:00.000       Euthanasia       Suffering       Other
# 688  2020-05-13T00:00:00.000       Euthanasia     Rabies Risk       Other
# 689  2021-08-13T00:00:00.000         Adoption             NaN       Other
# 690  2021-08-13T00:00:00.000         Adoption             NaN       Other
# 691  2021-08-13T00:00:00.000         Adoption             NaN       Other
# 710  2020-10-12T00:00:00.000         Adoption             NaN       Other
# 791  2020-05-07T00:00:00.000       Euthanasia     Rabies Risk       Other
# 792  2020-05-07T00:00:00.000       Euthanasia             NaN       Other
# 840  2022-04-06T00:00:00.000         Transfer         Partner       Other
# 841  2022-04-06T00:00:00.000         Transfer         Partner       Other
# 842  2021-10-06T00:00:00.000         Transfer         Partner       Other
# 843  2022-04-06T00:00:00.000         Transfer         Partner       Other
# 844  2019-05-02T00:00:00.000         Transfer         Partner       Other
# 845  2019-05-02T00:00:00.000         Transfer         Partner       Other
# 887  2021-05-09T00:00:00.000       Euthanasia     Rabies Risk       Other
# 903  2021-08-06T00:00:00.000         Transfer         Partner       Other
# 905  2020-05-06T00:00:00.000       Euthanasia     Rabies Risk       Other
#
#     sex_upon_outcome age_upon_outcome       breed           color  new_age1  \
# 127          Unknown          2 years         Bat           Brown   2 years
# 128          Unknown          2 years         Bat           Brown   2 years
# 173          Unknown             NULL         Bat           Brown      NULL
# 211          Unknown          2 years         Bat           Brown   2 years
# 220          Unknown          2 years         Bat           Brown   2 years
# 257          Unknown             NULL         Bat           Brown      NULL
# 264          Unknown             NULL         Bat           Brown      NULL
# 273          Unknown             NULL         Fox            Gray      NULL
# 274          Unknown             NULL         Fox            Gray      NULL
# 275          Unknown             NULL         Bat           Brown      NULL
# 294          Unknown          2 years     Raccoon      Gray/Black   2 years
# 299      Intact Male           1 year  Guinea Pig     Brown/White   1 years
# 300      Intact Male           1 year  Guinea Pig        Tricolor   1 years
# 316    Intact Female           1 year  Guinea Pig           Brown   1 years
# 389          Unknown          2 years         Bat     Brown/Brown   2 years
# 395    Neutered Male           1 year      Ferret     Brown/White   1 years
# 402          Unknown           1 year     Raccoon      Gray/Black   1 years
# 413          Unknown             NULL         Bat           Brown      NULL
# 414          Unknown          2 years     Raccoon      Black/Gray   2 years
# 446          Unknown           1 year         Fox        Red/Gray   1 years
# 460      Intact Male          2 years   Rabbit Sh           Black   2 years
# 461    Intact Female         6 months    Lionhead           Brown  6 months
# 462      Intact Male         6 months    Lionhead     White/Black  6 months
# 513          Unknown          2 years     Raccoon      Black/Gray   2 years
# 536          Unknown           1 year     Raccoon      Gray/Black   1 years
# 537          Unknown           1 year     Raccoon      Gray/Black   1 years
# 538          Unknown          2 years       Skunk     Black/White   2 years
# 539          Unknown           1 year     Raccoon           Brown   1 years
# 544          Unknown          2 years         Bat           Brown   2 years
# 548    Intact Female          2 years     Raccoon            Gray   2 years
# 676          Unknown           1 year    Squirrel           Brown   1 years
# 688          Unknown             NULL         Bat           Brown      NULL
# 689      Intact Male         8 months  Guinea Pig          Calico  8 months
# 690      Intact Male         8 months  Guinea Pig      White/Gray  8 months
# 691      Intact Male         8 months  Guinea Pig      White/Gray  8 months
# 710    Intact Female           1 year     Hamster     Brown/White   1 years
# 791          Unknown          2 years         Bat           Brown   2 years
# 792          Unknown          2 years         Bat           Brown   2 years
# 840      Intact Male          4 weeks  Guinea Pig        Tricolor   4 weeks
# 841      Intact Male          4 weeks  Guinea Pig        Tricolor   4 weeks
# 842    Intact Female         7 months  Guinea Pig  Tricolor/Black  7 months
# 843    Intact Female          4 weeks  Guinea Pig     Sable/White   4 weeks
# 844      Intact Male          3 years  Guinea Pig           Black   3 years
# 845      Intact Male          3 years  Guinea Pig       Tan/Black   3 years
# 887          Unknown           1 year       Skunk     Black/White   1 years
# 903      Intact Male         9 months  Guinea Pig     Sable/White  9 months
# 905          Unknown          2 years     Raccoon     Brown/Black   2 years
#
#     new_sex1
# 127  Unknown
# 128  Unknown
# 173  Unknown
# 211  Unknown
# 220  Unknown
# 257  Unknown
# 264  Unknown
# 273  Unknown
# 274  Unknown
# 275  Unknown
# 294  Unknown
# 299     Male
# 300     Male
# 316   Female
# 389  Unknown
# 395     Male
# 402  Unknown
# 413  Unknown
# 414  Unknown
# 446  Unknown
# 460     Male
# 461   Female
# 462     Male
# 513  Unknown
# 536  Unknown
# 537  Unknown
# 538  Unknown
# 539  Unknown
# 544  Unknown
# 548   Female
# 676  Unknown
# 688  Unknown
# 689     Male
# 690     Male
# 691     Male
# 710   Female
# 791  Unknown
# 792  Unknown
# 840     Male
# 841     Male
# 842   Female
# 843   Female
# 844     Male
# 845     Male
# 887  Unknown
# 903     Male
# 905  Unknown

# %%
animals['animal_type'].value_counts()
# Out:
# Dog      500
# Cat      450
# Other     47
# Bird       3
# Name: animal_type, dtype: int64

# %%
type(np.nan)
# Out:
# float

# %%
animals['animal_type'].map(lambda x: np.nan if x == 'Other' else x)\
.value_counts(
    #dropna=False
)
# Out:
# Dog     500
# Cat     450
# Bird      3
# Name: animal_type, dtype: int64

# %%
animals['animal_type'].value_counts()
# Out:
# Dog      500
# Cat      450
# Other     47
# Bird       3
# Name: animal_type, dtype: int64

# %%
#animals['animal_type'] = animals['animal_type'].map(lambda x: np.nan if x == 'Other' else x)

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# A lot of the times we'll have missing information in our data set. This can sometimes be troublesome in what we're trying to do.

# %% [markdown]
# So far, we've been doing some preprocessing/cleaning to answer questions. Now we're going to handle the missing values in our data.
#
# There are a few strategies we can choose from and they each have their special use case.

# %% [markdown]
# > Before making changes, it's convenient to make changes to a copy instead of overwriting data. We'll keep all our changes in `animals_clean` which will be a [copy](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html) of the original DataFrame.

# %%
animals_clean = animals.copy()

# %% [markdown]
# ## Fill with a Relevant Value

# %% [markdown]
# A lot of times we already have an idea of how we want to specify that a value was missing and replace it with a value that makes more sense than an "empty" value.

# %% [markdown]
# For example, it might make sense to fill the value as "MISSING" or "UNKNOWN". This way it's clearer when do more analysis.

# %% [markdown]
# > We can use Pandas' [`fillna()` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html) to replace missing values with something specific

# %%
# Note this creates a copy of `animals` with the missing values replaced
animals_name_filled = animals_clean.fillna({'name':'UNKNOWN'}) # {col_name:new_value}
animals_name_filled.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption             NaN         Dog
# 2  2022-02-28T00:00:00.000     Adoption             NaN         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1
# 0  Brown Brindle/White  3 months   Female
# 1             Tricolor   4 years     Male
# 2                 Blue  3 months   Female
# 3          White/Black   3 years     Male
# 4          Brown/White   6 years   Female

# %%
# `animals` DataFrame is left untouched
animals_clean.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption             NaN         Dog
# 2  2022-02-28T00:00:00.000     Adoption             NaN         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1
# 0  Brown Brindle/White  3 months   Female
# 1             Tricolor   4 years     Male
# 2                 Blue  3 months   Female
# 3          White/Black   3 years     Male
# 4          Brown/White   6 years   Female

# %%
# Alternative way to fill missing values by specifying column(s) first
animals_only_names = animals[['name']].fillna(value='UNKNOWN')
animals_only_names.head()
# Out:
#       name
# 0   *Adora
# 1     Jack
# 2  A855710
# 3  Cassidy
# 4     Coco

# %%
# To keep changes in DataFrame, overwrite the column
animals_clean[['name']] = animals_only_names
animals_clean.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption             NaN         Dog
# 2  2022-02-28T00:00:00.000     Adoption             NaN         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1
# 0  Brown Brindle/White  3 months   Female
# 1             Tricolor   4 years     Male
# 2                 Blue  3 months   Female
# 3          White/Black   3 years     Male
# 4          Brown/White   6 years   Female

# %% [markdown]
# ## Fill with a Reasonable Value

# %% [markdown]
# Other times we don't know what the missing value was but we might have a reasonable guess. This allows us to still use the data point (row) in our analysis.

# %% [markdown]
# > Beware that filling in missing values can lead to you drawing incorrect conclusions. If most of the data from a column are missing, it's going to appear that the value you filled it in with is more common that it actually was!

# %% [markdown]
# A lot of the time we'll use the _mean_ or _median_ for numerical values. Sometimes values like $0$ make sense since it might make sense in the context of how the data was collected.
#
# With categorical values, you might choose to fill the missing values with the most common value (the *mode*).

# %% [markdown]
# > Similar to the previous subsection, we can use the `fillna()` method after specifying the value to fill

# %%
## Let's find the most common value for `outcome_subtype`
outcome_subtype_counts = animals['outcome_subtype'].value_counts()
outcome_subtype_counts
# Out:
# Partner                249
# Foster                 106
# Out State               83
# Snr                     46
# Suffering               23
# Rabies Risk             23
# Field                   10
# In Kennel                4
# Aggressive               4
# In Foster                3
# Prc                      1
# Medical                  1
# At Vet                   1
# Court/Investigation      1
# Name: outcome_subtype, dtype: int64

# %%
# This gets us just the values in order of most frequent to least frequent
outcome_subtype_ordered = outcome_subtype_counts.index
print(outcome_subtype_ordered)

# Get the first one
most_common_outcome_subtype = outcome_subtype_ordered[0]
# Out:
# Index(['Partner', 'Foster', 'Out State', 'Snr', 'Suffering', 'Rabies Risk',
#        'Field', 'In Kennel', 'Aggressive', 'In Foster', 'Prc', 'Medical',
#        'At Vet', 'Court/Investigation'],
#       dtype='object')

# %%
most_common_outcome_subtype
# Out:
# 'Partner'

# %%
animals['outcome_subtype'].mode()
# Out:
# 0    Partner
# dtype: object

# %%
# Using the built-in mode() method
# Note this is Series so we have to get the first element (which is the value)
most_common_outcome_subtype = animals['outcome_subtype'].mode()[0]
most_common_outcome_subtype
# Out:
# 'Partner'

# %%
# Similar to the previous subsection, we can use fillna() and update the DF
animals_clean['outcome_subtype'] = animals['outcome_subtype']\
.fillna(most_common_outcome_subtype)
animals_clean.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption         Partner         Dog
# 2  2022-02-28T00:00:00.000     Adoption         Partner         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1
# 0  Brown Brindle/White  3 months   Female
# 1             Tricolor   4 years     Male
# 2                 Blue  3 months   Female
# 3          White/Black   3 years     Male
# 4          Brown/White   6 years   Female

# %% [markdown]
# ## Specify That the Data Were Missing

# %% [markdown]
# Even after filling in missing values, it might make sense to specify that there were missing data. You can document that the data was missing by creating a new column that represents whether the data was originally missing or not.

# %% [markdown]
# This can be helpful when you suspect that the fact the data was missing could be important for an analysis.

# %% [markdown]
# > Since we already removed some missing values, we're going to reference back to the original `animals` DataFrame. (Good thing we didn't overwrite it! 😉)

# %%
# Let's specify which values were originally missing in "outcome_subtype"
missing_outcome_subtypes = animals['outcome_subtype'].isna()
missing_outcome_subtypes
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999    False
# Name: outcome_subtype, Length: 1000, dtype: bool

# %%
# Create new column for missing outcome subtypes matched w/ replaced values
animals_clean['outcome_subtype_missing'] = missing_outcome_subtypes
animals_clean.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption         Partner         Dog
# 2  2022-02-28T00:00:00.000     Adoption         Partner         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1  outcome_subtype_missing
# 0  Brown Brindle/White  3 months   Female                    False
# 1             Tricolor   4 years     Male                     True
# 2                 Blue  3 months   Female                     True
# 3          White/Black   3 years     Male                    False
# 4          Brown/White   6 years   Female                    False

# %% [markdown]
# ## Drop Missing Data

# %% [markdown]
# You should try to keep as much relevant data as possible, but sometimes the other methods don't make as much sense and it's better to remove or **drop** the missing data.

# %% [markdown]
# We typically drop missing data if very little data would be lost and/or trying to fill in the values wouldn't make sense for our use case. For example, if you're trying to predict the outcome based on the other features/columns it might not make sense to fill in those missing values with something you can't confirm.

# %% [markdown]
# > We noticed that `outcome_type` had only a few missing values. It might not be worth trying to handle those few missing values. We can pretend that the `outcome_type` was an important feature and without it the rest of the row's data is of little importance to us.
# >
# > So we'll decide to drop the row if a value from `outcome_type` is missing. We'll use Pandas' [`dropna()` method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html).

# %%
animals_clean['outcome_type'].value_counts().sum()
# Out:
# 1000

# %%
# This will drop any row (axis=0) or column (axis=1) that has missing values
animals_clean = animals_clean.dropna(   # Note we're overwriting animals_clean
                                axis=0, # This is the default & will drop rows; axis=1 for cols
                                subset=['outcome_type'] # Specific labels to consider (defaults to all)
)
animals_clean.head()
# Out:
#   animal_id     name            datetime                monthyear  \
# 0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
#
#              date_of_birth outcome_type outcome_subtype animal_type  \
# 0  2022-02-13T00:00:00.000     Transfer         Partner         Dog
# 1  2018-05-18T00:00:00.000     Adoption         Partner         Dog
# 2  2022-02-28T00:00:00.000     Adoption         Partner         Cat
# 3  2018-10-04T00:00:00.000     Transfer         Partner         Dog
# 4  2015-10-02T00:00:00.000     Transfer         Partner         Dog
#
#   sex_upon_outcome age_upon_outcome                      breed  \
# 0    Spayed Female         3 months               Pit Bull Mix
# 1    Neutered Male          4 years     Labrador Retriever Mix
# 2    Spayed Female         3 months         Domestic Shorthair
# 3    Neutered Male          3 years  Australian Cattle Dog Mix
# 4    Intact Female          6 years                   Pit Bull
#
#                  color  new_age1 new_sex1  outcome_subtype_missing
# 0  Brown Brindle/White  3 months   Female                    False
# 1             Tricolor   4 years     Male                     True
# 2                 Blue  3 months   Female                     True
# 3          White/Black   3 years     Male                    False
# 4          Brown/White   6 years   Female                    False

# %%
animals_clean.shape
# Out:
# (1000, 15)

# %% [markdown]
# ## Comparing Before and After

# %% [markdown]
# We can now see all the work we did!

# %%
# Original data
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   animal_id         1000 non-null   object
#  1   name              829 non-null    object
#  2   datetime          1000 non-null   datetime64[ns]
#  3   monthyear         1000 non-null   object
#  4   date_of_birth     1000 non-null   object
#  5   outcome_type      1000 non-null   object
#  6   outcome_subtype   555 non-null    object
#  7   animal_type       1000 non-null   object
#  8   sex_upon_outcome  1000 non-null   object
#  9   age_upon_outcome  1000 non-null   object
#  10  breed             1000 non-null   object
#  11  color             1000 non-null   object
#  12  new_age1          1000 non-null   object
#  13  new_sex1          1000 non-null   object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 109.5+ KB

# %%
# Missing data cleaned
animals_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   animal_id                1000 non-null   object
#  1   name                     1000 non-null   object
#  2   datetime                 1000 non-null   datetime64[ns]
#  3   monthyear                1000 non-null   object
#  4   date_of_birth            1000 non-null   object
#  5   outcome_type             1000 non-null   object
#  6   outcome_subtype          1000 non-null   object
#  7   animal_type              1000 non-null   object
#  8   sex_upon_outcome         1000 non-null   object
#  9   age_upon_outcome         1000 non-null   object
#  10  breed                    1000 non-null   object
#  11  color                    1000 non-null   object
#  12  new_age1                 1000 non-null   object
#  13  new_sex1                 1000 non-null   object
#  14  outcome_subtype_missing  1000 non-null   bool
# dtypes: bool(1), datetime64[ns](1), object(13)
# memory usage: 118.2+ KB

# %%
animals_clean.reset_index()
# Out:
#      index animal_id     name            datetime                monthyear  \
# 0        0   A857248   *Adora 2022-06-02 19:01:00  2022-06-02T19:01:00.000
# 1        1   A857557     Jack 2022-06-02 18:47:00  2022-06-02T18:47:00.000
# 2        2   A855710  A855710 2022-06-02 17:39:00  2022-06-02T17:39:00.000
# 3        3   A854440  Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 4        4   A823946     Coco 2022-06-02 17:04:00  2022-06-02T17:04:00.000
# ..     ...       ...      ...                 ...                      ...
# 995    995   A856622  UNKNOWN 2022-05-05 18:07:00  2022-05-05T18:07:00.000
# 996    996   A856540   Bailey 2022-05-05 17:33:00  2022-05-05T17:33:00.000
# 997    997   A856625  UNKNOWN 2022-05-05 17:03:00  2022-05-05T17:03:00.000
# 998    998   A856037     Gina 2022-05-05 16:20:00  2022-05-05T16:20:00.000
# 999    999   A856563  A856563 2022-05-05 16:08:00  2022-05-05T16:08:00.000
#
#                date_of_birth     outcome_type outcome_subtype animal_type  \
# 0    2022-02-13T00:00:00.000         Transfer         Partner         Dog
# 1    2018-05-18T00:00:00.000         Adoption         Partner         Dog
# 2    2022-02-28T00:00:00.000         Adoption         Partner         Cat
# 3    2018-10-04T00:00:00.000         Transfer         Partner         Dog
# 4    2015-10-02T00:00:00.000         Transfer         Partner         Dog
# ..                       ...              ...             ...         ...
# 995  2020-05-05T00:00:00.000       Euthanasia       Suffering         Cat
# 996  2020-05-04T00:00:00.000  Return to Owner         Partner         Dog
# 997  2020-05-05T00:00:00.000  Return to Owner         Partner         Dog
# 998  2020-04-27T00:00:00.000         Adoption         Partner         Dog
# 999  2022-04-12T00:00:00.000         Transfer         Partner         Cat
#
#     sex_upon_outcome age_upon_outcome                      breed  \
# 0      Spayed Female         3 months               Pit Bull Mix
# 1      Neutered Male          4 years     Labrador Retriever Mix
# 2      Spayed Female         3 months         Domestic Shorthair
# 3      Neutered Male          3 years  Australian Cattle Dog Mix
# 4      Intact Female          6 years                   Pit Bull
# ..               ...              ...                        ...
# 995      Intact Male          2 years         Domestic Shorthair
# 996    Spayed Female          2 years             Bloodhound Mix
# 997          Unknown          2 years      Shetland Sheepdog Mix
# 998    Spayed Female          2 years        German Shepherd Mix
# 999    Intact Female          3 weeks     Domestic Shorthair Mix
#
#                    color  new_age1 new_sex1  outcome_subtype_missing
# 0    Brown Brindle/White  3 months   Female                    False
# 1               Tricolor   4 years     Male                     True
# 2                   Blue  3 months   Female                     True
# 3            White/Black   3 years     Male                    False
# 4            Brown/White   6 years   Female                    False
# ..                   ...       ...      ...                      ...
# 995                Black   2 years     Male                    False
# 996                Brown   2 years   Female                     True
# 997          Black/Brown   2 years  Unknown                     True
# 998          Black/Brown   2 years   Female                     True
# 999           Blue Tabby   3 weeks   Female                    False
#
# [1000 rows x 16 columns]

# %% [markdown]
# # Level Up: `.applymap()`

# %% [markdown]
# `.applymap()` is used to apply a transformation to each element of a DataFrame.

# %%
# This line will apply the base `type()` function to 
# all entries of the DataFrame.

animals.applymap(type)
# Out:
#          animal_id             name  \
# 0    <class 'str'>    <class 'str'>
# 1    <class 'str'>    <class 'str'>
# 2    <class 'str'>    <class 'str'>
# 3    <class 'str'>    <class 'str'>
# 4    <class 'str'>    <class 'str'>
# ..             ...              ...
# 995  <class 'str'>  <class 'float'>
# 996  <class 'str'>    <class 'str'>
# 997  <class 'str'>  <class 'float'>
# 998  <class 'str'>    <class 'str'>
# 999  <class 'str'>    <class 'str'>
#
#                                               datetime      monthyear  \
# 0    <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 1    <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 2    <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 3    <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 4    <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# ..                                                 ...            ...
# 995  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 996  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 997  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 998  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
# 999  <class 'pandas._libs.tslibs.timestamps.Timesta...  <class 'str'>
#
#      date_of_birth   outcome_type  outcome_subtype    animal_type  \
# 0    <class 'str'>  <class 'str'>    <class 'str'>  <class 'str'>
# 1    <class 'str'>  <class 'str'>  <class 'float'>  <class 'str'>
# 2    <class 'str'>  <class 'str'>  <class 'float'>  <class 'str'>
# 3    <class 'str'>  <class 'str'>    <class 'str'>  <class 'str'>
# 4    <class 'str'>  <class 'str'>    <class 'str'>  <class 'str'>
# ..             ...            ...              ...            ...
# 995  <class 'str'>  <class 'str'>    <class 'str'>  <class 'str'>
# 996  <class 'str'>  <class 'str'>  <class 'float'>  <class 'str'>
# 997  <class 'str'>  <class 'str'>  <class 'float'>  <class 'str'>
# 998  <class 'str'>  <class 'str'>  <class 'float'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>    <class 'str'>  <class 'str'>
#
#     sex_upon_outcome age_upon_outcome          breed          color  \
# 0      <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 1      <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 2      <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 3      <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 4      <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# ..               ...              ...            ...            ...
# 995    <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 996    <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 997    <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 998    <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
# 999    <class 'str'>    <class 'str'>  <class 'str'>  <class 'str'>
#
#           new_age1       new_sex1
# 0    <class 'str'>  <class 'str'>
# 1    <class 'str'>  <class 'str'>
# 2    <class 'str'>  <class 'str'>
# 3    <class 'str'>  <class 'str'>
# 4    <class 'str'>  <class 'str'>
# ..             ...            ...
# 995  <class 'str'>  <class 'str'>
# 996  <class 'str'>  <class 'str'>
# 997  <class 'str'>  <class 'str'>
# 998  <class 'str'>  <class 'str'>
# 999  <class 'str'>  <class 'str'>
#
# [1000 rows x 14 columns]

# %% [markdown]
# # Level Up: `pandas.Series.str`

# %% [markdown]
# To access normal `str` methods for each of the values in a categorical column of a DataFrame, use the following construction:

# %%
animals[animals['color'].str.contains('Black')]
# Out:
#     animal_id            name            datetime                monthyear  \
# 3     A854440         Cassidy 2022-06-02 17:06:00  2022-06-02T17:06:00.000
# 10    A850257          *Ronny 2022-06-02 15:20:00  2022-06-02T15:20:00.000
# 13    A857661      *Crabapple 2022-06-02 14:05:00  2022-06-02T14:05:00.000
# 17    A855892       *Macaroni 2022-06-02 12:46:00  2022-06-02T12:46:00.000
# 30    A858235            Plum 2022-06-01 17:53:00  2022-06-01T17:53:00.000
# ..        ...             ...                 ...                      ...
# 988   A852968            Loba 2022-05-06 10:56:00  2022-05-06T10:56:00.000
# 991   A855589  *Billy The Kid 2022-05-05 18:58:00  2022-05-05T18:58:00.000
# 995   A856622             NaN 2022-05-05 18:07:00  2022-05-05T18:07:00.000
# 997   A856625             NaN 2022-05-05 17:03:00  2022-05-05T17:03:00.000
# 998   A856037            Gina 2022-05-05 16:20:00  2022-05-05T16:20:00.000
#
#                date_of_birth     outcome_type outcome_subtype animal_type  \
# 3    2018-10-04T00:00:00.000         Transfer         Partner         Dog
# 10   2021-01-21T00:00:00.000         Adoption             NaN         Dog
# 13   2020-05-19T00:00:00.000         Adoption             NaN         Cat
# 17   2021-11-10T00:00:00.000         Adoption          Foster         Dog
# 30   2022-01-26T00:00:00.000  Return to Owner             NaN         Cat
# ..                       ...              ...             ...         ...
# 988  2014-03-23T00:00:00.000         Adoption          Foster         Dog
# 991  2021-04-20T00:00:00.000         Adoption             NaN         Dog
# 995  2020-05-05T00:00:00.000       Euthanasia       Suffering         Cat
# 997  2020-05-05T00:00:00.000  Return to Owner             NaN         Dog
# 998  2020-04-27T00:00:00.000         Adoption             NaN         Dog
#
#     sex_upon_outcome age_upon_outcome                       breed  \
# 3      Neutered Male          3 years   Australian Cattle Dog Mix
# 10     Neutered Male           1 year                    Pit Bull
# 13     Neutered Male          2 years          Domestic Shorthair
# 17     Neutered Male         6 months  Labrador Retriever/Pointer
# 30     Spayed Female         4 months      Domestic Shorthair Mix
# ..               ...              ...                         ...
# 988    Spayed Female          8 years             German Shepherd
# 991    Neutered Male           1 year             German Shepherd
# 995      Intact Male          2 years          Domestic Shorthair
# 997          Unknown          2 years       Shetland Sheepdog Mix
# 998    Spayed Female          2 years         German Shepherd Mix
#
#            color  new_age1 new_sex1
# 3    White/Black   3 years     Male
# 10   Black/White   1 years     Male
# 13   White/Black   2 years     Male
# 17   Black/White  6 months     Male
# 30         Black  4 months   Female
# ..           ...       ...      ...
# 988  Black/Brown   8 years   Female
# 991        Black   1 years     Male
# 995        Black   2 years     Male
# 997  Black/Brown   2 years  Unknown
# 998  Black/Brown   2 years   Female
#
# [295 rows x 14 columns]

# %% [markdown]
# # Level Up: Faster NumPy Methods

# %% [markdown]
# In general, `np.where()` and `np.select()` are faster than `map()`. This won't matter too much with reasonably-sized data but can be a consideration for ***big data***.

# %% [markdown]
# ## NumPy's `where()` Method

# %%
animals['new_age2'] = np.where(animals['age_upon_outcome'] == '1 year',
                              '1 years', animals['age_upon_outcome'])
animals['new_age2']
# Out:
# 0      3 months
# 1       4 years
# 2      3 months
# 3       3 years
# 4       6 years
#          ...
# 995     2 years
# 996     2 years
# 997     2 years
# 998     2 years
# 999     3 weeks
# Name: new_age2, Length: 1000, dtype: object

# %%
# Check we got the same results with np.where()
(animals['new_age1'] != animals['new_age2']).sum()
# Out:
# 0

# %%
# Let's time how long it takes .map() to run by running it multiple times
# %timeit animals['new_age1'] = animals['age_upon_outcome'].map(one_year)
# Out:
# 220 µs ± 4.21 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Let's time how long it takes np.where() to run by running it multiple times
# %timeit animals['new_age2'] = np.where(animals['age_upon_outcome'] == '1 year',\
                                       '1 years',animals['age_upon_outcome'])
# Out:
# 150 µs ± 1.48 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## NumPy's `select()` Method

# %% [markdown]
# Again, `numpy` will be faster:

# %%
conditions = [animals['sex_upon_outcome'] == 'Neutered Male',
             animals['sex_upon_outcome'] == 'Intact Male',
             animals['sex_upon_outcome'] == 'Spayed Female',
             animals['sex_upon_outcome'] == 'Intact Female',
             animals['sex_upon_outcome'] == 'Unknown',
             animals['sex_upon_outcome'] == 'NULL']

choices = ['Male', 'Male', 'Female', 'Female', 'Unknown', 'Unknown']

# %%
animals['new_sex2'] = np.select(conditions, choices)
animals['new_sex2']
# Out:
# 0       Female
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#         ...
# 995       Male
# 996     Female
# 997    Unknown
# 998     Female
# 999     Female
# Name: new_sex2, Length: 1000, dtype: object

# %%
# Check we got the same results with np.where()
(animals['new_sex1'] != animals['new_sex2']).sum()
# Out:
# 0

# %%
# Let's time how long it takes .map() to run by running it multiple times
# %timeit animals['new_sex1'] = animals['sex_upon_outcome'].map(sex_mapper)
# Out:
# 262 µs ± 4.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Let's time how long it takes np.select() to run by running it multiple times
# %timeit animals['new_sex2'] = np.select(conditions, choices)
